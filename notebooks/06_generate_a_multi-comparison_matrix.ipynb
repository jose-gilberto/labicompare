# %%
import pandas as pd
from labicompare.visualization import generate_mcm

# %%
metrics = pd.read_csv('./example_metrics.csv')
generate_mcm(metrics)
# Out:
# Processing KNN, DT:   0%|          | 0/6 [00:00<?, ?it/s] /home/gilberto/.local/lib/python3.12/site-packages/scipy/stats/_wilcoxon.py:199: UserWarning: Sample size too small for normal approximation.
#   temp = _wilcoxon_iv(x, y, zero_method, correction, alternative, method, axis)
# Processing SVM, NB:   0%|          | 0/6 [00:00<?, ?it/s]
